# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df.Category.describe()
# Out:
# count     5572
# unique       2
# top        ham
# freq      4825
# Name: Category, dtype: object

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x: 1 if x == 'spam' else 0)
df
# Out:
#      Category                                            Message  spam
# 0         ham  Go until jurong point, crazy.. Available only ...     0
# 1         ham                      Ok lar... Joking wif u oni...     0
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3         ham  U dun say so early hor... U c already then say...     0
# 4         ham  Nah I don't think he goes to usf, he lives aro...     0
# ...       ...                                                ...   ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...     1
# 5568      ham               Will ü b going to esplanade fr home?     0
# 5569      ham  Pity, * was in mood for that. So...any other s...     0
# 5570      ham  The guy did some bitching but I acted like i'd...     0
# 5571      ham                         Rofl. Its true to its name     0
#
# [5572 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:4]
# Out:
# 1569    Today is ACCEPT DAY..U Accept me as? Brother S...
# 3863                     Customer place, i wil cal u sir.
# 2153    Hi kindly give us back our documents which we ...
# 1094    Well the weather in cali's great. But its comp...
# Name: Message, dtype: object

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
y_test[:4]
# Out:
# 2481    1
# 1700    0
# 4294    0
# 3695    0
# Name: spam, dtype: int64

# %%
type(X_train.values)
# Out:
# numpy.ndarray

# %% [markdown]
# Create bag of words representation using CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <4457x7772 sparse matrix of type '<class 'numpy.int64'>'
# 	with 59619 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
X_train_cv.shape
# Out:
# (4457, 7772)

# %%
v.get_feature_names_out()
# Out:
# array(['00', '000', '000pes', ..., 'zyada', 'èn', 'ú1'], dtype=object)

# %%
v.vocabulary_
# Out:
# {'today': 6970,
#  'is': 3763,
#  'accept': 783,
#  'day': 2193,
#  'me': 4415,
#  'as': 1097,
#  'brother': 1532,
#  'sister': 6206,
#  'lover': 4241,
#  'dear1': 2207,
#  'best1': 1334,
#  'clos1': 1854,
#  'lvblefrnd': 4279,
#  'jstfrnd': 3877,
#  'cutefrnd': 2145,
#  'lifpartnr': 4116,
#  'belovd': 1324,
#  'swtheart': 6694,
#  'bstfrnd': 1544,
#  'no': 4795,
#  'rply': 5848,
#  'means': 4421,
#  'enemy': 2603,
#  'customer': 2140,
#  'place': 5228,
#  'wil': 7543,
#  'cal': 1608,
#  'sir': 6203,
#  'hi': 3432,
#  'kindly': 3956,
#  'give': 3156,
#  'us': 7246,
#  'back': 1201,
#  'our': 5013,
#  'documents': 2394,
#  'which': 7519,
#  'we': 7448,
#  'submitted': 6586,
#  'for': 2952,
#  'loan': 4179,
#  'from': 3032,
#  'stapati': 6467,
#  'well': 7484,
#  'the': 6848,
#  'weather': 7456,
#  'in': 3657,
#  'cali': 1611,
#  'great': 3245,
#  'but': 1582,
#  'its': 3782,
#  'complexities': 1944,
#  'are': 1064,
#  'you': 7736,
#  'need': 4728,
#  'car': 1656,
#  'to': 6964,
#  'move': 4608,
#  'freely': 3001,
#  'taxes': 6751,
#  'outrageous': 5023,
#  'all': 925,
#  'sad': 5885,
#  'part': 5089,
#  'missing': 4522,
#  'home': 3481,
#  'my': 4668,
#  'love': 4236,
#  'how': 3530,
#  'goes': 3179,
#  'that': 6844,
#  'fuck': 3041,
#  'this': 6888,
#  'morning': 4595,
#  'woke': 7600,
#  'and': 975,
#  'dropped': 2472,
#  'cell': 1716,
#  'on': 4940,
#  'way': 7444,
#  'down': 2439,
#  'stairs': 6458,
#  'it': 3774,
#  'seems': 6009,
#  'alright': 937,
#  'phews': 5181,
#  'miss': 4518,
#  'congratulations': 1976,
#  'ur': 7232,
#  'awarded': 1175,
#  '500': 542,
#  'of': 4896,
#  'cd': 1707,
#  'vouchers': 7361,
#  'or': 4979,
#  '125gift': 286,
#  'guaranteed': 3271,
#  'free': 2995,
#  'entry': 2632,
#  '100': 255,
#  'wkly': 7589,
#  'draw': 2451,
#  'txt': 7122,
#  'music': 4658,
#  '87066': 696,
#  'tncs': 6963,
#  'www': 7670,
#  'ldew': 4059,
#  'com1win150ppmx3age16': 1910,
#  'pay': 5116,
#  'lt': 4260,
#  'decimal': 2219,
#  'gt': 3268,
#  'lakhs': 4013,
#  'sorry': 6353,
#  'll': 4171,
#  'call': 1614,
#  'later': 4039,
#  'friends': 3017,
#  'can': 1638,
#  'stay': 6485,
#  'fb': 2810,
#  'chat': 1757,
#  'with': 7575,
#  'error': 2649,
#  've': 7293,
#  'always': 944,
#  'been': 1299,
#  'brainy': 1489,
#  'one': 4945,
#  'wat': 7427,
#  'time': 6932,
#  'finish': 2874,
#  'money': 4577,
#  'aint': 893,
#  'thing': 6879,
#  'sha': 6074,
#  'hows': 3534,
#  'champ': 1731,
#  'just': 3891,
#  'leaving': 4075,
#  'glasgow': 3161,
#  'guess': 3276,
#  'pub': 5494,
#  'im': 3629,
#  'happy': 3339,
#  'pig': 5211,
#  'clover': 1864,
#  'whatever': 7505,
#  'saying': 5944,
#  'vivek': 7346,
#  'got': 3211,
#  'your': 7740,
#  'number': 4857,
#  'mean': 4417,
#  'confirmed': 1970,
#  'tot': 7018,
#  'they': 6874,
#  'juz': 3896,
#  'say': 5941,
#  'oni': 4947,
#  'ok': 4919,
#  'then': 6861,
#  'town': 7027,
#  'important': 3646,
#  'yup': 7756,
#  'thk': 6889,
#  'so': 6303,
#  'until': 7211,
#  'shop': 6131,
#  'closes': 1859,
#  'lor': 4216,
#  'hmmm': 3463,
#  'many': 4356,
#  'players': 5243,
#  'selected': 6016,
#  '20': 345,
#  'cost': 2031,
#  'isnt': 3770,
#  'bad': 1203,
#  'ya': 7696,
#  'want': 7408,
#  'did': 2315,
#  'find': 2869,
#  'sitter': 6211,
#  'kaitlyn': 3903,
#  'was': 7421,
#  'sick': 6171,
#  'slept': 6246,
#  'yesterday': 7721,
#  'training': 7038,
#  'manual': 4355,
#  'show': 6150,
#  'there': 6866,
#  'tech': 6774,
#  'process': 5440,
#  'about': 768,
#  'password': 5103,
#  'reset': 5745,
#  'troubleshooting': 7076,
#  'am': 946,
#  'not': 4829,
#  'at': 1126,
#  'what': 7504,
#  'doing': 2409,
#  'urgent': 7235,
#  'last': 4033,
#  'weekend': 7471,
#  'shows': 6157,
#  'have': 3364,
#  'won': 7605,
#  '1000': 256,
#  'cash': 1683,
#  'spanish': 6380,
#  'holiday': 3476,
#  'now': 4843,
#  '09050000332': 162,
#  'claim': 1831,
#  'rstm': 5851,
#  'sw7': 6670,
#  '3ss': 471,
#  '150ppm': 309,
#  'he': 3374,
#  'like': 4124,
#  'shock': 6127,
#  'leh': 4083,
#  'cos': 2029,
#  'telling': 6786,
#  'shuhui': 6164,
#  'leona': 4091,
#  'also': 939,
#  'dat': 2183,
#  'almost': 932,
#  'know': 3974,
#  'liao': 4103,
#  'ask': 1105,
#  'abt': 775,
#  'reaction': 5607,
#  'take': 6717,
#  'any': 1009,
#  'major': 4330,
#  'roles': 5828,
#  'community': 1927,
#  'outreach': 5024,
#  'rock': 5821,
#  'mel': 4442,
#  'pussy': 5519,
#  'perfect': 5149,
#  'credits': 2081,
#  'topped': 7010,
#  'up': 7213,
#  'http': 3544,
#  'bubbletext': 1548,
#  'com': 1909,
#  'renewal': 5714,
#  'pin': 5217,
#  'tgxxrz': 6830,
#  'pure': 5511,
#  'hearted': 3390,
#  'person': 5161,
#  'wonderful': 7608,
#  'smile': 6273,
#  'makes': 4332,
#  'even': 2676,
#  'his': 3449,
#  'her': 3418,
#  'enemies': 2602,
#  'feel': 2819,
#  'guilty': 3283,
#  'being': 1317,
#  'an': 970,
#  'catch': 1693,
#  'world': 7628,
#  'goodmorning': 3199,
#  'amp': 962,
#  'smiley': 6276,
#  'sunday': 6630,
#  'dont': 2421,
#  'shall': 6083,
#  'buy': 1586,
#  'dear': 2206,
#  'people': 5144,
#  'be': 1277,
#  'special': 6388,
#  'first': 2886,
#  'sight': 6176,
#  'only': 4951,
#  'very': 7306,
#  'few': 2836,
#  'will': 7547,
#  'remain': 5696,
#  'till': 6931,
#  'maintain': 4328,
#  'them': 6857,
#  'life': 4112,
#  'ends': 2601,
#  'sh': 6073,
#  'jas': 3817,
#  'calls': 1629,
#  'messages': 4464,
#  'missed': 4520,
#  'eat': 2526,
#  'shit': 6119,
#  'wait': 7386,
#  'monkey': 4578,
#  'face': 2759,
#  'bitch': 1378,
#  'asshole': 1117,
#  'chance': 1734,
#  'reality': 5616,
#  'fantasy': 2791,
#  '08707509020': 86,
#  '20p': 355,
#  'per': 5146,
#  'min': 4489,
#  'ntt': 4851,
#  'ltd': 4261,
#  'po': 5266,
#  'box': 1462,
#  '1327': 293,
#  'croydon': 2095,
#  'cr9': 2062,
#  '5wb': 569,
#  '0870': 69,
#  'national': 4704,
#  'rate': 5585,
#  '2nd': 408,
#  'attempt': 1136,
#  'contract': 2001,
#  'weeks': 7474,
#  'top': 7007,
#  'prize': 5426,
#  'either': 2562,
#  '200': 346,
#  '09066361921': 226,
#  'new': 4760,
#  'mobiles': 4550,
#  '2004': 349,
#  'must': 4661,
#  'go': 3172,
#  'nokia': 4803,
#  '89545': 720,
#  'collect': 1899,
#  'yours': 7743,
#  'tc': 6758,
#  'biz': 1383,
#  '2optout': 412,
#  '087187262701': 140,
#  '50gbp': 546,
#  'mtmsg18': 4630,
#  'txtauction': 7126,
#  'hey': 3428,
#  'tmr': 6958,
#  'maybe': 4409,
#  'meet': 4433,
#  'yck': 7707,
#  'too': 6999,
#  'mark': 4366,
#  'taking': 6722,
#  'forever': 2956,
#  'pick': 5199,
#  'prescription': 5390,
#  'pain': 5056,
#  'coming': 1920,
#  'polyphonic': 5298,
#  'tone': 6988,
#  'mob': 4547,
#  'every': 2683,
#  'week': 7469,
#  'pt2': 5491,
#  '87575': 704,
#  '1st': 335,
#  'get': 3132,
#  'txtin': 7127,
#  'tell': 6785,
#  '150p': 305,
#  '16': 315,
#  'reply': 5728,
#  'hl': 3457,
#  '4info': 523,
#  'eldest': 2570,
#  'poking': 5288,
#  'man': 4341,
#  'everyday': 2687,
#  'teach': 6763,
#  'canada': 1639,
#  'abi': 763,
#  'princess': 5414,
#  'thank': 6835,
#  'pics': 5203,
#  'pretty': 5401,
#  'chase': 1754,
#  'after': 863,
#  'run': 5869,
#  'over': 5031,
#  'while': 7520,
#  'she': 6097,
#  'crossing': 2093,
#  'street': 6542,
#  'much': 4635,
#  'close': 1855,
#  'heart': 3389,
#  'if': 3611,
#  'away': 1176,
#  'shattered': 6094,
#  'plz': 5263,
#  'dun': 2498,
#  'ericsson': 2645,
#  'oso': 5003,
#  'cannot': 1648,
#  'oredi': 4990,
#  'lar': 4028,
#  'ttyl': 7095,
#  'grandfather': 3233,
#  'expired': 2738,
#  'leave': 4073,
#  'cant': 1649,
#  'display': 2368,
#  'internal': 3729,
#  'subs': 6589,
#  'gotta': 3217,
#  'extract': 2751,
#  'outside': 5026,
#  'islands': 3768,
#  'head': 3375,
#  'towards': 7026,
#  'hard': 3340,
#  'into': 3734,
#  'whats': 7506,
#  'todays': 6971,
#  'plan': 5233,
#  'other': 5005,
#  'charges': 1747,
#  'transfer': 7045,
#  'withdraw': 7576,
#  'anyhow': 1011,
#  'keep': 3923,
#  'ten': 6794,
#  'rs': 5850,
#  'shelf': 6101,
#  'two': 7121,
#  'egg': 2555,
#  'wats': 7439,
#  'opinion': 4967,
#  'him': 3442,
#  'character': 1744,
#  'good': 3195,
#  'thanx': 6841,
#  'exams': 2711,
#  'march': 4362,
#  'ive': 3788,
#  'done': 2419,
#  'revision': 5783,
#  'fran': 2985,
#  'still': 6511,
#  'boyf': 1480,
#  'interviw': 3732,
#  'exeter': 2721,
#  'bit': 1377,
#  'worried': 7631,
#  'babe': 1194,
#  'already': 936,
#  'loving': 4246,
#  'kiss': 3961,
#  'hope': 3498,
#  'everything': 2691,
#  'hear': 3385,
#  'settling': 6060,
#  'happenin': 3333,
#  'wit': 7574,
#  'ola': 4928,
#  'tessy': 6811,
#  'pls': 5257,
#  'do': 2386,
#  'favor': 2807,
#  'convey': 2006,
#  'birthday': 1375,
#  'wishes': 7570,
#  'nimya': 4784,
#  'dnt': 2385,
#  'forget': 2959,
#  'shijas': 6108,
#  'mm': 4536,
#  'yes': 7719,
#  'look': 4207,
#  'hugging': 3550,
#  'both': 1452,
#  'glad': 3160,
#  'talking': 6729,
#  'late': 4036,
#  'comin': 1919,
#  'fetch': 2833,
#  'howz': 3535,
#  'persons': 5166,
#  'story': 6534,
#  'fighting': 2847,
#  'easy': 2525,
#  'win': 7550,
#  'lose': 4218,
#  'bt': 1545,
#  'fightng': 2848,
#  'some1': 6319,
#  'who': 7524,
#  'dificult': 2329,
#  'lmao': 4174,
#  'nice': 4772,
#  'oh': 4914,
#  'den': 2259,
#  'muz': 4665,
#  'change': 1736,
#  'yan': 7700,
#  'jiu': 3844,
#  'again': 869,
#  'joys': 3872,
#  'lifeis': 4114,
#  'waking': 7391,
#  'each': 2511,
#  'daywith': 2196,
#  'thoughts': 6901,
#  'somewheresomeone': 6333,
#  'cares': 1669,
#  'enough': 2619,
#  'tosend': 7016,
#  'warm': 7415,
#  'greeting': 3251,
#  'mumhas': 4647,
#  'beendropping': 1300,
#  'red': 5659,
#  'wine': 7555,
#  'theplace': 6865,
#  'adress': 838,
#  'kitty': 3966,
#  'shaved': 6095,
#  'natural': 4707,
#  'yunny': 7754,
#  'goin': 3182,
#  'yeah': 7708,
#  'probs': 5439,
#  'night': 4779,
#  'obviously': 4885,
#  'catching': 1695,
#  'speak': 6386,
#  'soon': 6343,
#  'reading': 5610,
#  'gud': 3273,
#  'habit': 3296,
#  'nan': 4692,
#  'bari': 1235,
#  'hudgi': 3547,
#  'yorge': 7735,
#  'pataistha': 5106,
#  'ertini': 2651,
#  'kano': 3912,
#  'bus': 1575,
#  'calicut': 1612,
#  'information': 3690,
#  'orange': 4982,
#  'user': 7254,
#  '0796xxxxxx': 41,
#  'lucky': 4265,
#  'out': 5016,
#  'why': 7532,
#  'log': 4189,
#  'onto': 4954,
#  'urawinner': 7233,
#  'fantastic': 2790,
#  'prizeawaiting': 5427,
#  'honey': 3486,
#  'boo': 1432,
#  'chile': 1802,
#  'please': 5249,
#  'hour': 3522,
#  'drive': 2465,
#  'come': 1914,
#  'subletting': 6585,
#  'feb': 2814,
#  'april': 1055,
#  'audition': 1146,
#  'season': 5988,
#  'knows': 3976,
#  'lunch': 4270,
#  'menu': 4457,
#  'da': 2155,
#  'lol': 4197,
#  'busy': 1581,
#  'live': 4164,
#  '11': 268,
#  'secret': 5994,
#  'admirer': 832,
#  'looking': 4210,
#  'make': 4331,
#  'contact': 1990,
#  'reveal': 5778,
#  'thinks': 6885,
#  '09065171142': 218,
#  'stopsms': 6531,
#  '08718727870150ppm': 146,
#  'sent': 6039,
#  'scores': 5964,
#  'sophas': 6349,
#  'had': 3298,
#  'secondary': 5992,
#  'application': 1040,
#  'schools': 5958,
#  'think': 6881,
#  'thinking': 6884,
#  'applying': 1042,
#  'research': 5739,
#  'joke': 3857,
#  'ogunrinde': 4913,
#  'school': 5957,
#  'less': 4094,
#  'expensive': 2733,
#  'ones': 4946,
#  'most': 4599,
#  'sparkling': 6384,
#  'shopping': 6133,
#  'breaks': 1502,
#  '45': 501,
#  '0121': 4,
#  '2025050': 353,
#  'visit': 7340,
#  'shortbreaks': 6138,
#  'org': 4992,
#  'uk': 7152,
#  'put': 5520,
#  'save': 5936,
#  'wedding': 7464,
#  'lingerie': 4142,
#  'bridal': 1509,
#  'petticoatdreams': 5175,
#  'co': 1879,
#  'choose': 1817,
#  'superb': 6641,
#  'selection': 6017,
#  'delivery': 2254,
#  'brought': 1533,
#  'by': 1597,
#  'weddingfriend': 7465,
#  'dunno': 2500,
#  'lei': 4084,
#  'might': 4480,
#  'eatin': 2528,
#  'wif': 7539,
#  'frens': 3008,
#  'wan': 7403,
#  'remind': 5704,
#  'hrs': 3541,
#  'started': 6474,
#  'send': 6030,
#  'requests': 5735,
#  'came': 1633,
#  'bed': 1294,
#  'double': 2434,
#  'coins': 1892,
#  'factory': 2763,
#  'nitros': 4790,
#  'made': 4310,
#  'plans': 5239,
#  'years': 7710,
#  'haha': 3300,
#  'see': 6002,
#  'sec': 5990,
#  '400': 477,
#  'xmas': 7679,
#  'reward': 5784,
#  'waiting': 7389,
#  'computer': 1951,
#  'has': 3349,
#  'randomly': 5578,
#  'picked': 5200,
#  'loyal': 4253,
#  'mobile': 4549,
#  'customers': 2141,
#  'receive': 5638,
#  '09066380611': 232,
#  'getting': 3139,
#  'website': 7462,
#  'usual': 7261,
#  'guy': 3289,
#  'passed': 5100,
#  'ahold': 887,
#  'anybody': 1010,
#  'let': 4097,
#  'throw': 6910,
#  'complimentary': 1945,
#  'trip': 7069,
#  'eurodisinc': 2670,
#  'trav': 7052,
#  'aco': 805,
#  'entry41': 2633,
#  'dis': 2352,
#  '87121': 699,
#  '18': 320,
#  '50': 541,
#  'morefrmmob': 4592,
#  'shracomorsglsuplt': 6158,
#  '10': 254,
#  'ls1': 4256,
#  '3aj': 457,
#  'attend': 1137,
#  'phone': 5185,
#  'burger': 1569,
#  'king': 3957,
#  'wanna': 7406,
#  'play': 5240,
#  'footy': 2951,
#  'stadium': 6454,
#  'before': 1305,
#  'sept': 6043,
#  'large': 4030,
#  'super': 6640,
#  'coca': 1884,
#  'cola': 1893,
#  'walk': 7393,
#  'winner': 7558,
#  'arun': 1096,
#  'transfr': 7048,
#  'amt': 967,
#  'although': 942,
#  'told': 6979,
#  'baig': 1209,
#  'watches': 7430,
#  'really': 5620,
#  'watch': 7428,
#  'gave': 3100,
#  'fr': 2983,
#  'touched': 7023,
#  'fast': 2795,
#  'approaching': 1048,
#  'wish': 7568,
#  'year': 7709,
#  'sankranti': 5914,
#  'republic': 5733,
#  'valentines': 7276,
#  'shivratri': 6124,
#  'ugadi': 7145,
#  'fools': 2946,
#  'may': 4407,
#  'independence': 3676,
#  'friendship': 3019,
#  'mother': 4601,
#  'father': 2800,
#  'teachers': 6765,
#  'childrens': 1801,
#  'ganesh': 3084,
#  'festival': 2832,
#  'dasara': 2182,
#  'diwali': 2377,
#  'christmas': 1822,
#  'mornings': 4596,
#  'afternoons': 865,
#  'evenings': 2678,
#  'nights': 4781,
#  'rememberi': 5701,
#  'wishing': 7572,
#  'these': 6868,
#  'raj': 5565,
#  'wen': 7487,
#  'someone': 6322,
#  'definitely': 2238,
#  'touch': 7022,
#  'gdeve': 3110,
#  'darren': 2179,
#  'course': 2051,
#  'jus': 3890,
#  'went': 7488,
#  'sim': 6186,
#  'lim': 4132,
#  'mp3': 4615,
#  'player': 5242,
#  'celebrate': 1712,
#  'else': 2576,
#  'when': 7509,
#  'hostel': 3515,
#  'simply': 6190,
#  'sitting': 6213,
#  'watching': 7432,
#  'match': 4385,
#  'office': 4906,
#  'house': 3525,
#  'maid': 4322,
#  'murderer': 4654,
#  'coz': 2057,
#  'murdered': 4653,
#  'th': 6831,
#  'january': 3813,
#  'public': 5495,
#  'govt': 3220,
#  'instituitions': 3718,
#  'closed': 1857,
#  'including': 3666,
#  'post': 5327,
#  'bangbabes': 1223,
#  'order': 4986,
#  'should': 6144,
#  'service': 6051,
#  'msg': 4619,
#  'download': 2440,
#  'content': 1994,
#  'goto': 3216,
#  'wap': 7413,
#  'bangb': 1222,
#  'tv': 7111,
#  'internet': 3730,
#  'treat': 7059,
#  'aids': 889,
#  'patent': 5107,
#  'understand': 7176,
#  'message': 4462,
#  'wife': 7540,
#  'nt': 4849,
#  'parents': 5082,
#  'forgot': 2963,
#  'kids': 3947,
#  'work': 7622,
#  'colleagues': 1898,
#  'entered': 2622,
#  'cabin': 1602,
#  'pa': 5045,
#  'said': 5893,
#  'boss': 1449,
#  'felt': 2829,
#  'askd': 1106,
#  'invited': 3740,
#  'apartment': 1025,
#  'mind': 4492,
#  'bedroom': 1297,
#  'minute': 4507,
#  'sed': 6001,
#  'sexy': 6068,
#  'mood': 4588,
#  'minuts': 4509,
#  'latr': 4042,
#  'wid': 7537,
#  'cake': 1606,
#  'kidz': 3948,
#  'screaming': 5975,
#  'surprise': 6661,
#  'sofa': 6307,
#  'naked': 4684,
#  'valued': 7281,
#  'network': 4752,
#  'receivea': 5639,
#  '900': 731,
#  '09061701461': 194,
#  'code': 1888,
#  'kl341': 3967,
#  'valid': 7277,
#  '12': 279,
#  'hours': 3524,
#  'bucks': 1549,
#  'banks': 1225,
#  'fees': 2825,
#  'fixed': 2894,
#  'better': 1339,
#  'bank': 1224,
#  'ure': 7234,
#  'practical': 5354,
#  'lessons': 4096,
#  'start': 6473,
#  'june': 3887,
#  'hiya': 3456,
#  'didn': 2317,
#  'hav': 3360,
#  'signal': 6178,
#  'haven': 3366,
#  'seen': 6010,
#  'heard': 3386,
#  'neither': 4742,
#  'unusual': 7212,
#  'itself': 3783,
#  'case': 1682,
#  'sort': 6354,
#  'hugs': 3552,
#  'snogs': 6295,
#  'beautiful': 1284,
#  'truth': 7084,
#  'against': 870,
#  'gravity': 3241,
#  'read': 5608,
#  'carefully': 1667,
#  'feels': 2824,
#  'light': 4120,
#  'heavy': 3395,
#  'leaves': 4074,
#  'fine': 2871,
#  'subscriber': 6593,
#  'gift': 3146,
#  'voucher': 7360,
#  'receipt': 5636,
#  'correct': 2025,
#  'ans': 998,
#  'elvis': 2578,
#  'presleys': 5394,
#  'answer': 1000,
#  '80062': 645,
#  'where': 7513,
#  'dogbreath': 2401,
#  'sounding': 6364,
#  'jan': 3809,
#  'al': 906,
#  'paying': 5122,
#  'rent': 5717,
#  'past': 5105,
#  'months': 4587,
#  'charge': 1745,
#  'would': 7643,
#  'inconsiderate': 3669,
#  'nag': 4679,
#  'something': 6327,
#  'yourself': 7744,
#  'didnt': 2318,
#  'however': 3533,
#  'recession': 5645,
#  'wont': 7611,
#  'able': 767,
#  'month': 4584,
#  'hence': 3415,
#  'askin': 1108,
#  'ahead': 883,
#  'end': 2596,
#  'help': 3407,
#  'thanks': 6836,
#  'thts': 6916,
#  'god': 3177,
#  'birds': 1370,
#  'humans': 3558,
#  'some': 6318,
#  'frm': 3023,
#  'stop': 6523,
#  'knowing': 3975,
#  'ni8': 4770,
#  'slp': 6260,
#  'care': 1661,
#  'swt': 6693,
#  'dreams': 2455,
#  'muah': 4634,
#  'ignorant': 3615,
#  'long': 4203,
#  'hair': 3303,
#  'cutting': 2148,
#  'quite': 5545,
#  'short': 6136,
#  'alive': 924,
#  'figure': 2850,
#  'lovable': 4235,
#  'bcums': 1274,
#  'angry': 982,
#  'seriously': 6048,
#  'childish': 1798,
#  'true': 7079,
#  'showing': 6154,
#  'deep': 2229,
#  'affection': 854,
#  'luv': 4274,
#  'kettoda': 3934,
#  'manda': 4346,
#  'glo': 3163,
#  'page': 5052,
#  'okie': 4924,
#  'surely': 6656,
#  'result': 5767,
#  'offer': 4902,
#  'fancies': 2786,
#  '09058097218': 185,
#  'pobox': 5268,
#  'ls15hb': 4257,
#  'daily': 2162,
#  'text': 6818,
#  'favour': 2808,
#  'monday': 4575,
#  'next': 4768,
#  'full': 3050,
#  'gist': 3154,
#  'perumbavoor': 5169,
#  'nothing': 4834,
#  'happen': 3330,
#  'romantic': 5829,
#  'nite': 4789,
#  'scenery': 5954,
#  'meeting': 4435,
#  'jurong': 3889,
#  'point': 5285,
#  'crazy': 2073,
#  'available': 1160,
#  'bugis': 1557,
#  'la': 4000,
#  'buffet': 1555,
#  'cine': 1826,
#  'amore': 960,
#  'umma': 7158,
#  'vava': 7290,
#  'lot': 4224,
#  'yet': 7722,
#  'chikku': 1796,
#  'carry': 1678,
#  'disturbing': 2373,
#  'mr': 4616,
#  'sheffield': 6100,
#  'game': 3080,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([ 783, 1097, 1324, 1334, 1532, 1544, 1854, 2145, 2193, 2207, 2603,
#         3763, 3877, 4116, 4241, 4279, 4415, 4421, 4795, 5848, 6206, 6694,
#         6970]),)

# %%
X_train[:4]
# Out:
# 1569    Today is ACCEPT DAY..U Accept me as? Brother S...
# 3863                     Customer place, i wil cal u sir.
# 2153    Hi kindly give us back our documents which we ...
# 1094    Well the weather in cali's great. But its comp...
# Name: Message, dtype: object

# %%
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
X_test_cv = v.transform(X_test)

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       979
#            1       0.97      0.89      0.93       136
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.94      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1])

# %% [markdown]
# Train the model using sklearn pipeline and reduce number of lines of code

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       979
#            1       0.97      0.89      0.93       136
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.94      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
